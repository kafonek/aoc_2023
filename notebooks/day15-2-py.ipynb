# %%
from dataclasses import dataclass
from typing import Literal, Optional

def aoc_hash(word: str):
    value = 0
    for c in word:
        ascii_code = ord(c)
        value += ascii_code
        value = value * 17
        value = value % 256
    return value

@dataclass
class Word:
    label: str
    operation: Literal['=', '-']
    hash: int
    focal_length: Optional[int] = None

    @staticmethod
    def from_string(s: str):
        if '-' in s:
            operation = '-'
            label = s[:-1]
            h = aoc_hash(label)
            return Word(label=label, operation=operation, hash=h)
        else:
            operation = '='
            label, focal_length = s.split('=')
            h = aoc_hash(label)
            return Word(label=label, operation=operation, focal_length=int(focal_length), hash=h)

# %%
#text = "rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7".split(',')
text = open('../data/day15.txt').read().split(',')
words = [Word.from_string(word) for word in text]
words
# Out:
# [Word(label='bvm', operation='=', hash=53, focal_length=6),
#  Word(label='mn', operation='-', hash=91, focal_length=None),
#  Word(label='gt', operation='=', hash=251, focal_length=2),
#  Word(label='bc', operation='=', hash=53, focal_length=2),
#  Word(label='nfn', operation='=', hash=130, focal_length=1),
#  Word(label='cz', operation='-', hash=221, focal_length=None),
#  Word(label='ptq', operation='-', hash=229, focal_length=None),
#  Word(label='mt', operation='-', hash=193, focal_length=None),
#  Word(label='flj', operation='=', hash=124, focal_length=4),
#  Word(label='dmnj', operation='=', hash=121, focal_length=4),
#  Word(label='jppb', operation='=', hash=76, focal_length=9),
#  Word(label='vzzgbv', operation='-', hash=121, focal_length=None),
#  Word(label='ccj', operation='=', hash=192, focal_length=7),
#  Word(label='jbkdsm', operation='-', hash=139, focal_length=None),
#  Word(label='jfzcm', operation='-', hash=202, focal_length=None),
#  Word(label='zxf', operation='-', hash=152, focal_length=None),
#  Word(label='scjz', operation='=', hash=234, focal_length=5),
#  Word(label='gqz', operation='-', hash=98, focal_length=None),
#  Word(label='tbs', operation='-', hash=121, focal_length=None),
#  Word(label='qzcb', operation='-', hash=80, focal_length=None),
#  Word(label='jg', operation='=', hash=129, focal_length=7),
#  Word(label='nvz', operation='=', hash=94, focal_length=7),
#  Word(label='zf', operation='=', hash=128, focal_length=9),
#  Word(label='mkj', operation='-', hash=178, focal_length=None),
#  Word(label='nc', operation='=', hash=193, focal_length=7),
#  Word(label='gsnbj', operation='-', hash=132, focal_length=None),
#  Word(label='bcs', operation='-', hash=40, focal_length=None),
#  Word(label='cgb', operation='=', hash=188, focal_length=5),
#  Word(label='zljm', operation='=', hash=141, focal_length=7),
#  Word(label='fsqtxt', operation='=', hash=26, focal_length=3),
#  Word(label='zbm', operation='=', hash=57, focal_length=5),
#  Word(label='lnd', operation='-', hash=126, focal_length=None),
#  Word(label='ddf', operation='-', hash=206, focal_length=None),
#  Word(label='qx', operation='-', hash=137, focal_length=None),
#  Word(label='jc', operation='-', hash=61, focal_length=None),
#  Word(label='xh', operation='-', hash=96, focal_length=None),
#  Word(label='kxvc', operation='-', hash=236, focal_length=None),
#  Word(label='fzm', operation='-', hash=125, focal_length=None),
#  Word(label='sxfqnm', operation='=', hash=125, focal_length=1),
#  Word(label='lnd', operation='-', hash=126, focal_length=None),
#  Word(label='jrxgf', operation='=', hash=129, focal_length=8),
#  Word(label='zbm', operation='-', hash=57, focal_length=None),
#  Word(label='dp', operation='-', hash=84, focal_length=None),
#  Word(label='lj', operation='-', hash=246, focal_length=None),
#  Word(label='cqp', operation='-', hash=244, focal_length=None),
#  Word(label='bb', operation='=', hash=36, focal_length=4),
#  Word(label='clf', operation='-', hash=165, focal_length=None),
#  Word(label='msbxx', operation='-', hash=226, focal_length=None),
#  Word(label='vft', operation='-', hash=112, focal_length=None),
#  Word(label='nsstz', operation='-', hash=18, focal_length=None),
#  Word(label='scqj', operation='=', hash=193, focal_length=4),
#  Word(label='ns', operation='-', hash=209, focal_length=None),
#  Word(label='jjr', operation='=', hash=134, focal_length=1),
#  Word(label='lqzlm', operation='-', hash=96, focal_length=None),
#  Word(label='zdxd', operation='-', hash=58, focal_length=None),
#  Word(label='cf', operation='=', hash=137, focal_length=6),
#  Word(label='tbs', operation='-', hash=121, focal_length=None),
#  Word(label='vb', operation='=', hash=184, focal_length=9),
#  Word(label='nbk', operation='-', hash=203, focal_length=None),
#  Word(label='bdt', operation='=', hash=90, focal_length=3),
#  Word(label='lhd', operation='=', hash=184, focal_length=8),
#  Word(label='tzmz', operation='=', hash=245, focal_length=9),
#  Word(label='rpc', operation='=', hash=213, focal_length=3),
#  Word(label='rnx', operation='-', hash=248, focal_length=None),
#  Word(label='lhhbz', operation='-', hash=56, focal_length=None),
#  Word(label='vdt', operation='=', hash=46, focal_length=7),
#  Word(label='kqq', operation='=', hash=141, focal_length=3),
#  Word(label='np', operation='-', hash=158, focal_length=None),
#  Word(label='cqk', operation='=', hash=159, focal_length=9),
#  Word(label='hcld', operation='-', hash=235, focal_length=None),
#  Word(label='fsqtxt', operation='-', hash=26, focal_length=None),
#  Word(label='vglgq', operation='-', hash=241, focal_length=None),
#  Word(label='xrn', operation='-', hash=248, focal_length=None),
#  Word(label='xnvv', operation='=', hash=146, focal_length=3),
#  Word(label='ccj', operation='=', hash=192, focal_length=5),
#  Word(label='zf', operation='-', hash=128, focal_length=None),
#  Word(label='kc', operation='=', hash=94, focal_length=7),
#  Word(label='jbkdsm', operation='=', hash=139, focal_length=1),
#  Word(label='vpl', operation='=', hash=50, focal_length=1),
#  Word(label='hx', operation='=', hash=96, focal_length=9),
#  Word(label='mc', operation='-', hash=160, focal_length=None),
#  Word(label='hk', operation='-', hash=131, focal_length=None),
#  Word(label='qk', operation='-', hash=172, focal_length=None),
#  Word(label='nc', operation='=', hash=193, focal_length=1),
#  Word(label='tsnv', operation='=', hash=123, focal_length=9),
#  Word(label='dztd', operation='=', hash=86, focal_length=4),
#  Word(label='bgv', operation='-', hash=223, focal_length=None),
#  Word(label='tt', operation='=', hash=168, focal_length=1),
#  Word(label='hqh', operation='-', hash=97, focal_length=None),
#  Word(label='ljr', operation='=', hash=232, focal_length=4),
#  Word(label='znb', operation='=', hash=10, focal_length=9),
#  Word(label='qzcb', operation='=', hash=80, focal_length=3),
#  Word(label='prf', operation='-', hash=232, focal_length=None),
#  Word(label='jn', operation='=', hash=248, focal_length=9),
#  Word(label='bdt', operation='-', hash=90, focal_length=None),
#  Word(label='xr', operation='-', hash=10, focal_length=None),
#  Word(label='vpl', operation='=', hash=50, focal_length=3),
#  Word(label='pkx', operation='=', hash=51, focal_length=7),
#  Word(label='vdt', operation='=', hash=46, focal_length=7),
#  Word(label='zt', operation='-', hash=110, focal_length=None),
#  Word(label='rv', operation='=', hash=136, focal_length=2),
#  Word(label='bkx', operation='-', hash=133, focal_length=None),
#  Word(label='cpc', operation='=', hash=246, focal_length=4),
#  Word(label='cf', operation='-', hash=137, focal_length=None),
#  Word(label='fk', operation='=', hash=65, focal_length=4),
#  Word(label='mrx', operation='-', hash=135, focal_length=None),
#  Word(label='qrz', operation='=', hash=109, focal_length=6),
#  Word(label='ljjg', operation='=', hash=55, focal_length=5),
#  Word(label='qhbl', operation='-', hash=103, focal_length=None),
#  Word(label='fsqtxt', operation='-', hash=26, focal_length=None),
#  Word(label='cg', operation='-', hash=154, focal_length=None),
#  Word(label='kncgk', operation='-', hash=30, focal_length=None),
#  Word(label='jjr', operation='=', hash=134, focal_length=2),
#  Word(label='jqrkf', operation='-', hash=158, focal_length=None),
#  Word(label='sdjrvt', operation='=', hash=221, focal_length=7),
#  Word(label='msv', operation='=', hash=134, focal_length=6),
#  Word(label='hxl', operation='=', hash=140, focal_length=1),
#  Word(label='czgrc', operation='=', hash=73, focal_length=8),
#  Word(label='hx', operation='=', hash=96, focal_length=9),
#  Word(label='dsxh', operation='=', hash=199, focal_length=9),
#  Word(label='nrv', operation='=', hash=150, focal_length=5),
#  Word(label='hqb', operation='-', hash=251, focal_length=None),
#  Word(label='xt', operation='=', hash=44, focal_length=6),
#  Word(label='szs', operation='=', hash=96, focal_length=2),
#  Word(label='hbq', operation='-', hash=11, focal_length=None),
#  Word(label='vs', operation='-', hash=217, focal_length=None),
#  Word(label='dsb', operation='=', hash=121, focal_length=7),
#  Word(label='fzm', operation='-', hash=125, focal_length=None),
#  Word(label='sb', operation='-', hash=85, focal_length=None),
#  Word(label='rn', operation='-', hash=0, focal_length=None),
#  Word(label='smc', operation='-', hash=163, focal_length=None),
#  Word(label='fxnx', operation='-', hash=4, focal_length=None),
#  Word(label='zx', operation='-', hash=178, focal_length=None),
#  Word(label='clf', operation='-', hash=165, focal_length=None),
#  Word(label='xmp', operation='-', hash=117, focal_length=None),
#  Word(label='ktp', operation='=', hash=223, focal_length=6),
#  Word(label='kch', operation='=', hash=38, focal_length=3),
#  Word(label='xnvv', operation='=', hash=146, focal_length=9),
#  Word(label='cg', operation='=', hash=154, focal_length=5),
#  Word(label='rzd', operation='-', hash=48, focal_length=None),
#  Word(label='mbm', operation='=', hash=188, focal_length=8),
#  Word(label='qfp', operation='=', hash=55, focal_length=1),
#  Word(label='sn', operation='-', hash=33, focal_length=None),
#  Word(label='gvmct', operation='-', hash=225, focal_length=None),
#  Word(label='pnq', operation='=', hash=31, focal_length=9),
#  Word(label='zljm', operation='-', hash=141, focal_length=None),
#  Word(label='hcld', operation='-', hash=235, focal_length=None),
#  Word(label='ddf', operation='-', hash=206, focal_length=None),
#  Word(label='cbkm', operation='-', hash=237, focal_length=None),
#  Word(label='qt', operation='=', hash=69, focal_length=7),
#  Word(label='rngsk', operation='-', hash=165, focal_length=None),
#  Word(label='gqgd', operation='-', hash=179, focal_length=None),
#  Word(label='qzcb', operation='-', hash=80, focal_length=None),
#  Word(label='qvmctp', operation='-', hash=43, focal_length=None),
#  Word(label='sn', operation='-', hash=33, focal_length=None),
#  Word(label='hq', operation='=', hash=233, focal_length=3),
#  Word(label='cd', operation='-', hash=103, focal_length=None),
#  Word(label='kph', operation='-', hash=211, focal_length=None),
#  Word(label='zxf', operation='-', hash=152, focal_length=None),
#  Word(label='zgxn', operation='=', hash=119, focal_length=4),
#  Word(label='tbdbvh', operation='-', hash=58, focal_length=None),
#  Word(label='qttxq', operation='-', hash=98, focal_length=None),
#  Word(label='dndl', operation='-', hash=130, focal_length=None),
#  Word(label='vdt', operation='=', hash=46, focal_length=9),
#  Word(label='qnc', operation='-', hash=98, focal_length=None),
#  Word(label='qbbbv', operation='=', hash=221, focal_length=7),
#  Word(label='bh', operation='-', hash=138, focal_length=None),
#  Word(label='vrgf', operation='-', hash=213, focal_length=None),
#  Word(label='jf', operation='=', hash=112, focal_length=4),
#  Word(label='rv', operation='=', hash=136, focal_length=9),
#  Word(label='tcllf', operation='-', hash=53, focal_length=None),
#  Word(label='lq', operation='-', hash=109, focal_length=None),
#  Word(label='qpp', operation='=', hash=129, focal_length=1),
#  Word(label='tcllf', operation='=', hash=53, focal_length=6),
#  Word(label='bpq', operation='-', hash=179, focal_length=None),
#  Word(label='ff', operation='=', hash=236, focal_length=5),
#  Word(label='cpc', operation='-', hash=246, focal_length=None),
#  Word(label='qtj', operation='-', hash=159, focal_length=None),
#  Word(label='zfxr', operation='=', hash=138, focal_length=4),
#  Word(label='rvt', operation='-', hash=188, focal_length=None),
#  Word(label='lk', operation='=', hash=7, focal_length=8),
#  Word(label='lb', operation='=', hash=110, focal_length=2),
#  Word(label='xt', operation='=', hash=44, focal_length=7),
#  Word(label='hq', operation='-', hash=233, focal_length=None),
#  Word(label='dn', operation='=', hash=50, focal_length=5),
#  Word(label='gkms', operation='-', hash=82, focal_length=None),
#  Word(label='vpl', operation='=', hash=50, focal_length=8),
#  Word(label='gscr', operation='-', hash=127, focal_length=None),
#  Word(label='jm', operation='-', hash=231, focal_length=None),
#  Word(label='npkcv', operation='=', hash=82, focal_length=2),
#  Word(label='dv', operation='-', hash=186, focal_length=None),
#  Word(label='jbkdsm', operation='-', hash=139, focal_length=None),
#  Word(label='bb', operation='=', hash=36, focal_length=5),
#  Word(label='pkx', operation='-', hash=51, focal_length=None),
#  Word(label='plm', operation='=', hash=153, focal_length=5),
#  Word(label='hvh', operation='=', hash=6, focal_length=9),
#  Word(label='skj', operation='=', hash=216, focal_length=9),
#  Word(label='sb', operation='-', hash=85, focal_length=None),
#  Word(label='qvm', operation='=', hash=20, focal_length=3),
#  Word(label='hq', operation='-', hash=233, focal_length=None),
#  Word(label='gqgd', operation='=', hash=179, focal_length=4),
#  Word(label='dfm', operation='-', hash=135, focal_length=None),
#  Word(label='tbs', operation='-', hash=121, focal_length=None),
#  Word(label='cg', operation='-', hash=154, focal_length=None),
#  Word(label='fv', operation='-', hash=252, focal_length=None),
#  Word(label='xmp', operation='-', hash=117, focal_length=None),
#  Word(label='kxn', operation='=', hash=65, focal_length=2),
#  Word(label='nv', operation='-', hash=4, focal_length=None),
#  Word(label='tsbk', operation='-', hash=52, focal_length=None),
#  Word(label='fsqs', operation='=', hash=29, focal_length=7),
#  Word(label='fsqs', operation='=', hash=29, focal_length=5),
#  Word(label='pc', operation='=', hash=3, focal_length=1),
#  Word(label='ptq', operation='-', hash=229, focal_length=None),
#  Word(label='xpsf', operation='-', hash=129, focal_length=None),
#  Word(label='dbx', operation='-', hash=190, focal_length=None),
#  Word(label='jx', operation='-', hash=162, focal_length=None),
#  Word(label='gds', operation='=', hash=62, focal_length=8),
#  Word(label='ndhl', operation='=', hash=166, focal_length=5),
#  Word(label='ctck', operation='-', hash=53, focal_length=None),
#  Word(label='fxlq', operation='-', hash=75, focal_length=None),
#  Word(label='grs', operation='=', hash=12, focal_length=8),
#  Word(label='bvm', operation='-', hash=53, focal_length=None),
#  Word(label='dpcsth', operation='-', hash=86, focal_length=None),
#  Word(label='scqj', operation='-', hash=193, focal_length=None),
#  Word(label='qt', operation='-', hash=69, focal_length=None),
#  Word(label='dfm', operation='-', hash=135, focal_length=None),
#  Word(label='rzkj', operation='=', hash=33, focal_length=4),
#  Word(label='hqb', operation='-', hash=251, focal_length=None),
#  Word(label='cf', operation='-', hash=137, focal_length=None),
#  Word(label='lmzdj', operation='=', hash=33, focal_length=6),
#  Word(label='bvm', operation='=', hash=53, focal_length=7),
#  Word(label='kph', operation='=', hash=211, focal_length=5),
#  Word(label='ctck', operation='=', hash=53, focal_length=6),
#  Word(label='mmh', operation='-', hash=210, focal_length=None),
#  Word(label='mzc', operation='=', hash=42, focal_length=6),
#  Word(label='nsstz', operation='-', hash=18, focal_length=None),
#  Word(label='vqk', operation='-', hash=66, focal_length=None),
#  Word(label='hk', operation='-', hash=131, focal_length=None),
#  Word(label='xjx', operation='-', hash=154, focal_length=None),
#  Word(label='gthv', operation='-', hash=153, focal_length=None),
#  Word(label='ghg', operation='-', hash=246, focal_length=None),
#  Word(label='rxglp', operation='-', hash=157, focal_length=None),
#  Word(label='mmh', operation='=', hash=210, focal_length=4),
#  Word(label='dp', operation='=', hash=84, focal_length=4),
#  Word(label='lb', operation='-', hash=110, focal_length=None),
#  Word(label='ckp', operation='-', hash=46, focal_length=None),
#  Word(label='tcjb', operation='=', hash=147, focal_length=7),
#  Word(label='nzq', operation='=', hash=73, focal_length=2),
#  Word(label='rvt', operation='=', hash=188, focal_length=3),
#  Word(label='zv', operation='-', hash=144, focal_length=None),
#  Word(label='jmq', operation='=', hash=216, focal_length=3),
#  Word(label='qvmctp', operation='-', hash=43, focal_length=None),
#  Word(label='cz', operation='-', hash=221, focal_length=None),
#  Word(label='xrn', operation='-', hash=248, focal_length=None),
#  Word(label='fx', operation='=', hash=30, focal_length=9),
#  Word(label='sn', operation='-', hash=33, focal_length=None),
#  Word(label='zlv', operation='=', hash=28, focal_length=7),
#  Word(label='vdk', operation='=', hash=149, focal_length=8),
#  Word(label='sdjrvt', operation='=', hash=221, focal_length=6),
#  Word(label='zhqdqm', operation='=', hash=197, focal_length=6),
#  Word(label='rzd', operation='-', hash=48, focal_length=None),
#  Word(label='qzcb', operation='-', hash=80, focal_length=None),
#  Word(label='gkms', operation='-', hash=82, focal_length=None),
#  Word(label='cbgh', operation='-', hash=20, focal_length=None),
#  Word(label='vdhc', operation='=', hash=21, focal_length=6),
#  Word(label='rkx', operation='=', hash=149, focal_length=6),
#  Word(label='fxvvt', operation='=', hash=62, focal_length=4),
#  Word(label='fzb', operation='=', hash=194, focal_length=1),
#  Word(label='zlbv', operation='-', hash=30, focal_length=None),
#  Word(label='qfp', operation='=', hash=55, focal_length=7),
#  Word(label='qvm', operation='-', hash=20, focal_length=None),
#  Word(label='pkx', operation='=', hash=51, focal_length=3),
#  Word(label='fxlq', operation='=', hash=75, focal_length=6),
#  Word(label='nrv', operation='-', hash=150, focal_length=None),
#  Word(label='qrz', operation='-', hash=109, focal_length=None),
#  Word(label='tbdbvh', operation='=', hash=58, focal_length=3),
#  Word(label='kqd', operation='=', hash=176, focal_length=3),
#  Word(label='sj', operation='=', hash=221, focal_length=7),
#  Word(label='cj', operation='-', hash=205, focal_length=None),
#  Word(label='kqb', operation='-', hash=142, focal_length=None),
#  Word(label='tc', operation='-', hash=135, focal_length=None),
#  Word(label='nrp', operation='=', hash=48, focal_length=1),
#  Word(label='qqvn', operation='=', hash=214, focal_length=9),
#  Word(label='pmq', operation='-', hash=254, focal_length=None),
#  Word(label='kqq', operation='=', hash=141, focal_length=4),
#  Word(label='kmpq', operation='-', hash=249, focal_length=None),
#  Word(label='ljq', operation='=', hash=215, focal_length=3),
#  Word(label='ksxkbn', operation='=', hash=209, focal_length=5),
#  Word(label='drbrb', operation='=', hash=140, focal_length=7),
#  Word(label='np', operation='=', hash=158, focal_length=8),
#  Word(label='lxkb', operation='=', hash=177, focal_length=5),
#  Word(label='sgfv', operation='-', hash=230, focal_length=None),
#  Word(label='tcc', operation='=', hash=138, focal_length=4),
#  Word(label='mx', operation='-', hash=5, focal_length=None),
#  Word(label='rj', operation='=', hash=188, focal_length=1),
#  Word(label='xk', operation='-', hash=147, focal_length=None),
#  Word(label='xpsf', operation='-', hash=129, focal_length=None),
#  Word(label='skc', operation='=', hash=97, focal_length=6),
#  Word(label='kjzp', operation='=', hash=159, focal_length=7),
#  Word(label='gn', operation='-', hash=149, focal_length=None),
#  Word(label='xjd', operation='-', hash=70, focal_length=None),
#  Word(label='gsnbj', operation='=', hash=132, focal_length=5),
#  Word(label='ccj', operation='=', hash=192, focal_length=1),
#  Word(label='ql', operation='=', hash=189, focal_length=9),
#  Word(label='xrn', operation='-', hash=248, focal_length=None),
#  Word(label='sz', operation='=', hash=237, focal_length=1),
#  Word(label='tbs', operation='-', hash=121, focal_length=None),
#  Word(label='dc', operation='=', hash=119, focal_length=7),
#  Word(label='hjjd', operation='-', hash=0, focal_length=None),
#  Word(label='smb', operation='=', hash=146, focal_length=5),
#  Word(label='kp', operation='-', hash=59, focal_length=None),
#  Word(label='fxt', operation='-', hash=178, focal_length=None),
#  Word(label='qpp', operation='-', hash=129, focal_length=None),
#  Word(label='lb', operation='-', hash=110, focal_length=None),
#  Word(label='nz', operation='-', hash=72, focal_length=None),
#  Word(label='mn', operation='-', hash=91, focal_length=None),
#  Word(label='bpq', operation='-', hash=179, focal_length=None),
#  Word(label='rxglp', operation='=', hash=157, focal_length=3),
#  Word(label='kbp', operation='-', hash=141, focal_length=None),
#  Word(label='rn', operation='-', hash=0, focal_length=None),
#  Word(label='qhdf', operation='-', hash=67, focal_length=None),
#  Word(label='gkms', operation='-', hash=82, focal_length=None),
#  Word(label='qnc', operation='-', hash=98, focal_length=None),
#  Word(label='gxjgv', operation='-', hash=118, focal_length=None),
#  Word(label='hz', operation='=', hash=130, focal_length=4),
#  Word(label='dhpbb', operation='=', hash=160, focal_length=7),
#  Word(label='cbgh', operation='-', hash=20, focal_length=None),
#  Word(label='lszh', operation='=', hash=17, focal_length=5),
#  Word(label='gds', operation='=', hash=62, focal_length=5),
#  Word(label='mmrbd', operation='-', hash=66, focal_length=None),
#  Word(label='mcl', operation='-', hash=204, focal_length=None),
#  Word(label='qnm', operation='-', hash=12, focal_length=None),
#  Word(label='lgzsh', operation='=', hash=104, focal_length=9),
#  Word(label='fsqtxt', operation='=', hash=26, focal_length=8),
#  Word(label='rzkj', operation='=', hash=33, focal_length=1),
#  Word(label='fzm', operation='=', hash=125, focal_length=7),
#  Word(label='xr', operation='-', hash=10, focal_length=None),
#  Word(label='ztsqm', operation='-', hash=223, focal_length=None),
#  Word(label='zgf', operation='=', hash=103, focal_length=3),
#  Word(label='dp', operation='-', hash=84, focal_length=None),
#  Word(label='lzb', operation='=', hash=232, focal_length=6),
#  Word(label='vjqsfl', operation='=', hash=70, focal_length=4),
#  Word(label='km', operation='=', hash=8, focal_length=6),
#  Word(label='chf', operation='=', hash=33, focal_length=9),
#  Word(label='vlftj', operation='=', hash=70, focal_length=8),
#  Word(label='zpjcm', operation='-', hash=84, focal_length=None),
#  Word(label='xrn', operation='=', hash=248, focal_length=3),
#  Word(label='qk', operation='=', hash=172, focal_length=1),
#  Word(label='vb', operation='-', hash=184, focal_length=None),
#  Word(label='ptq', operation='=', hash=229, focal_length=8),
#  Word(label='zs', operation='-', hash=93, focal_length=None),
#  Word(label='fv', operation='-', hash=252, focal_length=None),
#  Word(label='hb', operation='=', hash=234, focal_length=2),
#  Word(label='kqd', operation='-', hash=176, focal_length=None),
#  Word(label='pm', operation='=', hash=173, focal_length=7),
#  Word(label='kv', operation='=', hash=161, focal_length=1),
#  Word(label='kph', operation='-', hash=211, focal_length=None),
#  Word(label='vdhc', operation='=', hash=21, focal_length=7),
#  Word(label='dsxl', operation='=', hash=11, focal_length=8),
#  Word(label='xf', operation='=', hash=62, focal_length=6),
#  Word(label='ckp', operation='=', hash=46, focal_length=9),
#  Word(label='dm', operation='-', hash=33, focal_length=None),
#  Word(label='phv', operation='=', hash=174, focal_length=4),
#  Word(label='rm', operation='-', hash=239, focal_length=None),
#  Word(label='ft', operation='=', hash=218, focal_length=3),
#  Word(label='qbbbv', operation='=', hash=221, focal_length=2),
#  Word(label='bdt', operation='-', hash=90, focal_length=None),
#  Word(label='qmdpz', operation='=', hash=28, focal_length=8),
#  Word(label='mx', operation='-', hash=5, focal_length=None),
#  Word(label='nprdk', operation='-', hash=15, focal_length=None),
#  Word(label='cnn', operation='-', hash=111, focal_length=None),
#  Word(label='gf', operation='=', hash=13, focal_length=8),
#  Word(label='nq', operation='=', hash=175, focal_length=5),
#  Word(label='nsstz', operation='=', hash=18, focal_length=7),
#  Word(label='gld', operation='=', hash=71, focal_length=7),
#  Word(label='bvm', operation='=', hash=53, focal_length=5),
#  Word(label='jfdk', operation='=', hash=111, focal_length=7),
#  Word(label='kz', operation='=', hash=229, focal_length=8),
#  Word(label='skj', operation='-', hash=216, focal_length=None),
#  Word(label='msv', operation='-', hash=134, focal_length=None),
#  Word(label='cdn', operation='-', hash=37, focal_length=None),
#  Word(label='qnc', operation='=', hash=98, focal_length=5),
#  Word(label='hlr', operation='-', hash=102, focal_length=None),
#  Word(label='prf', operation='-', hash=232, focal_length=None),
#  Word(label='btfm', operation='=', hash=121, focal_length=7),
#  Word(label='vd', operation='=', hash=218, focal_length=1),
#  Word(label='pc', operation='=', hash=3, focal_length=7),
#  Word(label='tsf', operation='=', hash=205, focal_length=9),
#  Word(label='fn', operation='-', hash=116, focal_length=None),
#  Word(label='vkxq', operation='-', hash=106, focal_length=None),
#  Word(label='kb', operation='-', hash=77, focal_length=None),
#  Word(label='bjkmj', operation='=', hash=126, focal_length=4),
#  Word(label='xbx', operation='-', hash=146, focal_length=None),
#  Word(label='jx', operation='-', hash=162, focal_length=None),
#  Word(label='fq', operation='=', hash=167, focal_length=1),
#  Word(label='fm', operation='=', hash=99, focal_length=9),
#  Word(label='fk', operation='-', hash=65, focal_length=None),
#  Word(label='cr', operation='-', hash=85, focal_length=None),
#  Word(label='rpc', operation='=', hash=213, focal_length=5),
#  Word(label='mc', operation='-', hash=160, focal_length=None),
#  Word(label='dsb', operation='-', hash=121, focal_length=None),
#  Word(label='vv', operation='=', hash=12, focal_length=3),
#  Word(label='nvz', operation='-', hash=94, focal_length=None),
#  Word(label='jt', operation='=', hash=94, focal_length=6),
#  Word(label='kth', operation='=', hash=87, focal_length=2),
#  Word(label='bgv', operation='-', hash=223, focal_length=None),
#  Word(label='vqk', operation='-', hash=66, focal_length=None),
#  Word(label='vss', operation='=', hash=12, focal_length=7),
#  Word(label='mmh', operation='=', hash=210, focal_length=8),
#  Word(label='nfn', operation='-', hash=130, focal_length=None),
#  Word(label='zjlc', operation='=', hash=195, focal_length=1),
#  Word(label='fjdjn', operation='=', hash=76, focal_length=9),
#  Word(label='mx', operation='=', hash=5, focal_length=3),
#  Word(label='tzx', operation='=', hash=230, focal_length=8),
#  Word(label='fxt', operation='=', hash=178, focal_length=9),
#  Word(label='ggz', operation='=', hash=24, focal_length=1),
#  Word(label='nzqn', operation='=', hash=39, focal_length=7),
#  Word(label='lrspkv', operation='-', hash=66, focal_length=None),
#  Word(label='vdt', operation='=', hash=46, focal_length=7),
#  Word(label='vhbdb', operation='-', hash=230, focal_length=None),
#  Word(label='mmnhjn', operation='=', hash=152, focal_length=2),
#  Word(label='qpp', operation='-', hash=129, focal_length=None),
#  Word(label='xpsf', operation='-', hash=129, focal_length=None),
#  Word(label='pc', operation='-', hash=3, focal_length=None),
#  Word(label='vjqsfl', operation='-', hash=70, focal_length=None),
#  Word(label='vss', operation='-', hash=12, focal_length=None),
#  Word(label='qv', operation='-', hash=103, focal_length=None),
#  Word(label='fjdjn', operation='-', hash=76, focal_length=None),
#  Word(label='jx', operation='=', hash=162, focal_length=9),
#  Word(label='tmd', operation='=', hash=229, focal_length=7),
#  Word(label='gk', operation='-', hash=98, focal_length=None),
#  Word(label='sr', operation='=', hash=101, focal_length=9),
#  Word(label='nzqn', operation='=', hash=39, focal_length=5),
#  Word(label='tbdbvh', operation='-', hash=58, focal_length=None),
#  Word(label='xt', operation='-', hash=44, focal_length=None),
#  Word(label='dr', operation='=', hash=118, focal_length=8),
#  Word(label='th', operation='=', hash=220, focal_length=8),
#  Word(label='vkxq', operation='=', hash=106, focal_length=1),
#  Word(label='rdz', operation='=', hash=208, focal_length=7),
#  Word(label='vvbv', operation='=', hash=4, focal_length=1),
#  Word(label='hzr', operation='-', hash=52, focal_length=None),
#  Word(label='lln', operation='-', hash=230, focal_length=None),
#  Word(label='jp', operation='=', hash=26, focal_length=9),
#  Word(label='vdd', operation='-', hash=30, focal_length=None),
#  Word(label='gnzd', operation='=', hash=147, focal_length=2),
#  Word(label='vpgfjs', operation='-', hash=32, focal_length=None),
#  Word(label='zkhm', operation='=', hash=26, focal_length=9),
#  Word(label='lt', operation='-', hash=160, focal_length=None),
#  Word(label='nz', operation='-', hash=72, focal_length=None),
#  Word(label='zn', operation='-', hash=8, focal_length=None),
#  Word(label='gld', operation='-', hash=71, focal_length=None),
#  Word(label='qxrc', operation='-', hash=238, focal_length=None),
#  Word(label='tcm', operation='=', hash=52, focal_length=3),
#  Word(label='qtj', operation='=', hash=159, focal_length=6),
#  Word(label='lg', operation='=', hash=195, focal_length=9),
#  Word(label='sj', operation='=', hash=221, focal_length=6),
#  Word(label='mmnhjn', operation='=', hash=152, focal_length=6),
#  Word(label='jn', operation='-', hash=248, focal_length=None),
#  Word(label='lt', operation='=', hash=160, focal_length=2),
#  Word(label='zxf', operation='-', hash=152, focal_length=None),
#  Word(label='lln', operation='-', hash=230, focal_length=None),
#  Word(label='gf', operation='=', hash=13, focal_length=3),
#  Word(label='scjz', operation='-', hash=234, focal_length=None),
#  Word(label='bn', operation='-', hash=240, focal_length=None),
#  Word(label='fv', operation='=', hash=252, focal_length=9),
#  Word(label='vft', operation='=', hash=112, focal_length=5),
#  Word(label='xr', operation='=', hash=10, focal_length=4),
#  Word(label='fxvvt', operation='=', hash=62, focal_length=2),
#  Word(label='rc', operation='-', hash=69, focal_length=None),
#  Word(label='qj', operation='=', hash=155, focal_length=2),
#  Word(label='gx', operation='=', hash=63, focal_length=9),
#  Word(label='lntx', operation='=', hash=102, focal_length=6),
#  Word(label='rzd', operation='=', hash=48, focal_length=6),
#  Word(label='sxfqnm', operation='=', hash=125, focal_length=4),
#  Word(label='dn', operation='=', hash=50, focal_length=2),
#  Word(label='fsqsc', operation='=', hash=128, focal_length=1),
#  Word(label='rvt', operation='-', hash=188, focal_length=None),
#  Word(label='qrz', operation='-', hash=109, focal_length=None),
#  Word(label='kkq', operation='-', hash=199, focal_length=None),
#  Word(label='vpgfjs', operation='-', hash=32, focal_length=None),
#  Word(label='jbsv', operation='=', hash=85, focal_length=1),
#  Word(label='bblqrt', operation='-', hash=151, focal_length=None),
#  Word(label='gg', operation='-', hash=30, focal_length=None),
#  Word(label='dqsc', operation='-', hash=107, focal_length=None),
#  Word(label='gskl', operation='=', hash=33, focal_length=9),
#  Word(label='kch', operation='=', hash=38, focal_length=6),
#  Word(label='zkhm', operation='=', hash=26, focal_length=8),
#  Word(label='xkl', operation='=', hash=239, focal_length=4),
#  Word(label='gp', operation='-', hash=183, focal_length=None),
#  Word(label='pmdhcb', operation='-', hash=126, focal_length=None),
#  Word(label='jn', operation='-', hash=248, focal_length=None),
#  Word(label='kncgk', operation='=', hash=30, focal_length=4),
#  Word(label='phv', operation='-', hash=174, focal_length=None),
#  Word(label='tzx', operation='=', hash=230, focal_length=5),
#  Word(label='fjdjn', operation='=', hash=76, focal_length=8),
#  Word(label='vprd', operation='=', hash=188, focal_length=9),
#  Word(label='rz', operation='-', hash=204, focal_length=None),
#  Word(label='ll', operation='-', hash=24, focal_length=None),
#  Word(label='pjf', operation='=', hash=224, focal_length=2),
#  Word(label='tbdbvh', operation='=', hash=58, focal_length=6),
#  Word(label='bb', operation='-', hash=36, focal_length=None),
#  Word(label='hzr', operation='-', hash=52, focal_length=None),
#  Word(label='vrgf', operation='-', hash=213, focal_length=None),
#  Word(label='fk', operation='-', hash=65, focal_length=None),
#  Word(label='mrx', operation='-', hash=135, focal_length=None),
#  Word(label='zj', operation='=', hash=196, focal_length=3),
#  Word(label='fsqtxt', operation='=', hash=26, focal_length=6),
#  Word(label='rhltg', operation='=', hash=241, focal_length=2),
#  Word(label='qkpg', operation='=', hash=115, focal_length=5),
#  Word(label='lgzsh', operation='-', hash=104, focal_length=None),
#  Word(label='slsz', operation='-', hash=204, focal_length=None),
#  Word(label='bpq', operation='-', hash=179, focal_length=None),
#  Word(label='szs', operation='-', hash=96, focal_length=None),
#  Word(label='vdt', operation='=', hash=46, focal_length=8),
#  Word(label='ppnc', operation='=', hash=161, focal_length=4),
#  Word(label='pq', operation='-', hash=241, focal_length=None),
#  Word(label='fsqsc', operation='=', hash=128, focal_length=4),
#  Word(label='hdt', operation='-', hash=128, focal_length=None),
#  Word(label='fkk', operation='=', hash=108, focal_length=9),
#  Word(label='tmd', operation='=', hash=229, focal_length=1),
#  Word(label='vzzgbv', operation='-', hash=121, focal_length=None),
#  Word(label='ztrtr', operation='-', hash=102, focal_length=None),
#  Word(label='vglgq', operation='=', hash=241, focal_length=8),
#  Word(label='mx', operation='-', hash=5, focal_length=None),
#  Word(label='ff', operation='-', hash=236, focal_length=None),
#  Word(label='prf', operation='=', hash=232, focal_length=3),
#  Word(label='qj', operation='=', hash=155, focal_length=4),
#  Word(label='prf', operation='=', hash=232, focal_length=6),
#  Word(label='lz', operation='-', hash=6, focal_length=None),
#  Word(label='bpq', operation='-', hash=179, focal_length=None),
#  Word(label='kph', operation='-', hash=211, focal_length=None),
#  Word(label='mhxd', operation='=', hash=177, focal_length=5),
#  Word(label='kxn', operation='=', hash=65, focal_length=7),
#  Word(label='nzv', operation='=', hash=158, focal_length=7),
#  Word(label='gvh', operation='-', hash=213, focal_length=None),
#  Word(label='bscdp', operation='=', hash=124, focal_length=6),
#  Word(label='gnzd', operation='=', hash=147, focal_length=3),
#  Word(label='nv', operation='-', hash=4, focal_length=None),
#  Word(label='xrn', operation='=', hash=248, focal_length=9),
#  Word(label='qtn', operation='=', hash=227, focal_length=1),
#  Word(label='lt', operation='-', hash=160, focal_length=None),
#  Word(label='btfm', operation='-', hash=121, focal_length=None),
#  Word(label='cz', operation='-', hash=221, focal_length=None),
#  Word(label='ttmsd', operation='-', hash=124, focal_length=None),
#  Word(label='ktp', operation='-', hash=223, focal_length=None),
#  Word(label='kb', operation='-', hash=77, focal_length=None),
#  Word(label='qmdpz', operation='-', hash=28, focal_length=None),
#  Word(label='gvmct', operation='-', hash=225, focal_length=None),
#  Word(label='pjdr', operation='=', hash=48, focal_length=5),
#  Word(label='gld', operation='=', hash=71, focal_length=2),
#  Word(label='nzqn', operation='-', hash=39, focal_length=None),
#  Word(label='dt', operation='-', hash=152, focal_length=None),
#  Word(label='lc', operation='=', hash=127, focal_length=6),
#  Word(label='tbdbvh', operation='=', hash=58, focal_length=6),
#  Word(label='msldhq', operation='-', hash=41, focal_length=None),
#  Word(label='pcd', operation='-', hash=215, focal_length=None),
#  Word(label='jqr', operation='=', hash=109, focal_length=9),
#  Word(label='jcb', operation='=', hash=143, focal_length=2),
#  Word(label='nf', operation='-', hash=244, focal_length=None),
#  Word(label='scqj', operation='=', hash=193, focal_length=4),
#  Word(label='bb', operation='-', hash=36, focal_length=None),
#  Word(label='lk', operation='=', hash=7, focal_length=9),
#  Word(label='chht', operation='=', hash=39, focal_length=8),
#  Word(label='bx', operation='=', hash=154, focal_length=8),
#  Word(label='kjzp', operation='-', hash=159, focal_length=None),
#  Word(label='lhd', operation='=', hash=184, focal_length=9),
#  Word(label='lgzsh', operation='=', hash=104, focal_length=9),
#  Word(label='bgv', operation='-', hash=223, focal_length=None),
#  Word(label='tcm', operation='-', hash=52, focal_length=None),
#  Word(label='dmnj', operation='=', hash=121, focal_length=2),
#  Word(label='szn', operation='-', hash=11, focal_length=None),
#  Word(label='lcc', operation='=', hash=2, focal_length=9),
#  Word(label='cj', operation='-', hash=205, focal_length=None),
#  Word(label='sbk', operation='-', hash=192, focal_length=None),
#  Word(label='vdd', operation='=', hash=30, focal_length=3),
#  Word(label='mn', operation='-', hash=91, focal_length=None),
#  Word(label='cdf', operation='=', hash=157, focal_length=2),
#  Word(label='nh', operation='-', hash=22, focal_length=None),
#  Word(label='fjdjn', operation='=', hash=76, focal_length=4),
#  Word(label='zpf', operation='-', hash=144, focal_length=None),
#  Word(label='dm', operation='=', hash=33, focal_length=1),
#  Word(label='xq', operation='-', hash=249, focal_length=None),
#  Word(label='rnx', operation='-', hash=248, focal_length=None),
#  Word(label='qkg', operation='=', hash=67, focal_length=9),
#  Word(label='nzv', operation='=', hash=158, focal_length=2),
#  Word(label='ft', operation='-', hash=218, focal_length=None),
#  Word(label='zlv', operation='-', hash=28, focal_length=None),
#  Word(label='gsnbj', operation='=', hash=132, focal_length=7),
#  Word(label='hb', operation='=', hash=234, focal_length=9),
#  Word(label='gnf', operation='=', hash=171, focal_length=3),
#  Word(label='kkq', operation='=', hash=199, focal_length=5),
#  Word(label='fsqs', operation='=', hash=29, focal_length=7),
#  Word(label='nprdk', operation='-', hash=15, focal_length=None),
#  Word(label='fxvvt', operation='-', hash=62, focal_length=None),
#  Word(label='mmmznv', operation='=', hash=213, focal_length=4),
#  Word(label='ml', operation='-', hash=57, focal_length=None),
#  Word(label='mc', operation='=', hash=160, focal_length=4),
#  Word(label='mx', operation='-', hash=5, focal_length=None),
#  Word(label='rz', operation='=', hash=204, focal_length=6),
#  Word(label='zfjdds', operation='-', hash=21, focal_length=None),
#  Word(label='sz', operation='=', hash=237, focal_length=5),
#  Word(label='nfn', operation='-', hash=130, focal_length=None),
#  Word(label='mt', operation='=', hash=193, focal_length=3),
#  Word(label='md', operation='=', hash=177, focal_length=2),
#  Word(label='qnc', operation='-', hash=98, focal_length=None),
#  Word(label='plm', operation='=', hash=153, focal_length=4),
#  Word(label='phv', operation='-', hash=174, focal_length=None),
#  Word(label='kmpq', operation='=', hash=249, focal_length=2),
#  Word(label='dn', operation='=', hash=50, focal_length=5),
#  Word(label='btfm', operation='-', hash=121, focal_length=None),
#  Word(label='pkx', operation='-', hash=51, focal_length=None),
#  Word(label='ksxkbn', operation='=', hash=209, focal_length=9),
#  Word(label='qnc', operation='-', hash=98, focal_length=None),
#  Word(label='kth', operation='-', hash=87, focal_length=None),
#  Word(label='lh', operation='=', hash=212, focal_length=9),
#  Word(label='zktn', operation='=', hash=183, focal_length=2),
#  Word(label='zrqm', operation='-', hash=154, focal_length=None),
#  Word(label='qqvn', operation='-', hash=214, focal_length=None),
#  Word(label='qqlx', operation='=', hash=54, focal_length=2),
#  Word(label='kth', operation='=', hash=87, focal_length=5),
#  Word(label='lxkb', operation='-', hash=177, focal_length=None),
#  Word(label='qn', operation='=', hash=223, focal_length=3),
#  Word(label='msbxx', operation='-', hash=226, focal_length=None),
#  Word(label='qpv', operation='-', hash=231, focal_length=None),
#  Word(label='qz', operation='=', hash=171, focal_length=3),
#  Word(label='dhpbb', operation='-', hash=160, focal_length=None),
#  Word(label='gmn', operation='-', hash=18, focal_length=None),
#  Word(label='lt', operation='=', hash=160, focal_length=1),
#  Word(label='xjd', operation='=', hash=70, focal_length=8),
#  Word(label='lsk', operation='=', hash=154, focal_length=4),
#  Word(label='jbkdsm', operation='=', hash=139, focal_length=9),
#  Word(label='sx', operation='=', hash=203, focal_length=1),
#  Word(label='nbd', operation='=', hash=84, focal_length=6),
#  Word(label='zljm', operation='=', hash=141, focal_length=7),
#  Word(label='ks', operation='-', hash=110, focal_length=None),
#  Word(label='jgmh', operation='-', hash=150, focal_length=None),
#  Word(label='pk', operation='=', hash=139, focal_length=9),
#  Word(label='kjzp', operation='=', hash=159, focal_length=3),
#  Word(label='zrqm', operation='=', hash=154, focal_length=8),
#  Word(label='zfjdds', operation='-', hash=21, focal_length=None),
#  Word(label='qrnx', operation='-', hash=169, focal_length=None),
#  Word(label='ff', operation='=', hash=236, focal_length=3),
#  Word(label='jb', operation='-', hash=44, focal_length=None),
#  Word(label='ck', operation='-', hash=222, focal_length=None),
#  Word(label='fn', operation='=', hash=116, focal_length=2),
#  Word(label='dsb', operation='=', hash=121, focal_length=3),
#  Word(label='nvz', operation='-', hash=94, focal_length=None),
#  Word(label='gthv', operation='=', hash=153, focal_length=2),
#  Word(label='njnn', operation='-', hash=180, focal_length=None),
#  Word(label='frz', operation='=', hash=82, focal_length=8),
#  Word(label='dqsc', operation='=', hash=107, focal_length=9),
#  Word(label='gnt', operation='-', hash=153, focal_length=None),
#  Word(label='rh', operation='=', hash=154, focal_length=8),
#  Word(label='zt', operation='-', hash=110, focal_length=None),
#  Word(label='qfp', operation='-', hash=55, focal_length=None),
#  Word(label='chk', operation='=', hash=118, focal_length=2),
#  Word(label='qf', operation='=', hash=87, focal_length=9),
#  Word(label='gx', operation='=', hash=63, focal_length=8),
#  Word(label='lntx', operation='-', hash=102, focal_length=None),
#  Word(label='kh', operation='-', hash=179, focal_length=None),
#  Word(label='rf', operation='=', hash=120, focal_length=8),
#  Word(label='ls', operation='-', hash=143, focal_length=None),
#  Word(label='lsk', operation='-', hash=154, focal_length=None),
#  Word(label='zn', operation='-', hash=8, focal_length=None),
#  Word(label='jb', operation='=', hash=44, focal_length=7),
#  Word(label='kxn', operation='=', hash=65, focal_length=2),
#  Word(label='bx', operation='-', hash=154, focal_length=None),
#  Word(label='qhbl', operation='-', hash=103, focal_length=None),
#  Word(label='nc', operation='-', hash=193, focal_length=None),
#  Word(label='bscdp', operation='=', hash=124, focal_length=7),
#  Word(label='lq', operation='=', hash=109, focal_length=5),
#  Word(label='jc', operation='-', hash=61, focal_length=None),
#  Word(label='skj', operation='-', hash=216, focal_length=None),
#  Word(label='rvcc', operation='=', hash=222, focal_length=8),
#  Word(label='gp', operation='-', hash=183, focal_length=None),
#  Word(label='xpsf', operation='=', hash=129, focal_length=2),
#  Word(label='tk', operation='=', hash=15, focal_length=4),
#  Word(label='lcd', operation='-', hash=19, focal_length=None),
#  Word(label='md', operation='-', hash=177, focal_length=None),
#  Word(label='scv', operation='=', hash=156, focal_length=3),
#  Word(label='lzvgs', operation='=', hash=166, focal_length=4),
#  Word(label='cqp', operation='-', hash=244, focal_length=None),
#  Word(label='kjzp', operation='-', hash=159, focal_length=None),
#  Word(label='vxv', operation='=', hash=228, focal_length=1),
#  Word(label='pk', operation='-', hash=139, focal_length=None),
#  Word(label='gvmct', operation='=', hash=225, focal_length=3),
#  Word(label='fjdjn', operation='=', hash=76, focal_length=7),
#  Word(label='jcb', operation='=', hash=143, focal_length=5),
#  Word(label='hcld', operation='=', hash=235, focal_length=8),
#  Word(label='hmm', operation='-', hash=50, focal_length=None),
#  Word(label='chht', operation='=', hash=39, focal_length=9),
#  Word(label='msldhq', operation='-', hash=41, focal_length=None),
#  Word(label='bf', operation='=', hash=104, focal_length=4),
#  Word(label='nbh', operation='=', hash=152, focal_length=8),
#  Word(label='tsnv', operation='-', hash=123, focal_length=None),
#  Word(label='qdv', operation='-', hash=91, focal_length=None),
#  Word(label='skj', operation='-', hash=216, focal_length=None),
#  Word(label='vxv', operation='-', hash=228, focal_length=None),
#  Word(label='mcl', operation='-', hash=204, focal_length=None),
#  Word(label='zk', operation='=', hash=213, focal_length=1),
#  Word(label='dfp', operation='=', hash=186, focal_length=2),
#  Word(label='dtqq', operation='=', hash=170, focal_length=2),
#  Word(label='smc', operation='-', hash=163, focal_length=None),
#  Word(label='jbsv', operation='=', hash=85, focal_length=5),
#  Word(label='qlf', operation='-', hash=83, focal_length=None),
#  Word(label='vft', operation='-', hash=112, focal_length=None),
#  Word(label='dj', operation='-', hash=238, focal_length=None),
#  Word(label='zx', operation='=', hash=178, focal_length=5),
#  Word(label='pc', operation='-', hash=3, focal_length=None),
#  Word(label='fxvvt', operation='-', hash=62, focal_length=None),
#  Word(label='ptl', operation='-', hash=144, focal_length=None),
#  Word(label='pfmq', operation='-', hash=132, focal_length=None),
#  Word(label='tn', operation='-', hash=66, focal_length=None),
#  Word(label='gskl', operation='=', hash=33, focal_length=2),
#  Word(label='qc', operation='-', hash=36, focal_length=None),
#  Word(label='tt', operation='-', hash=168, focal_length=None),
#  Word(label='dr', operation='=', hash=118, focal_length=8),
#  Word(label='mkj', operation='=', hash=178, focal_length=2),
#  Word(label='nf', operation='=', hash=244, focal_length=5),
#  Word(label='lzb', operation='=', hash=232, focal_length=8),
#  Word(label='ll', operation='-', hash=24, focal_length=None),
#  Word(label='fxlq', operation='=', hash=75, focal_length=3),
#  Word(label='dl', operation='-', hash=16, focal_length=None),
#  Word(label='sj', operation='-', hash=221, focal_length=None),
#  Word(label='bblqrt', operation='=', hash=151, focal_length=2),
#  Word(label='hgz', operation='-', hash=73, focal_length=None),
#  Word(label='mmrbd', operation='=', hash=66, focal_length=8),
#  Word(label='xts', operation='-', hash=143, focal_length=None),
#  Word(label='mm', operation='-', hash=74, focal_length=None),
#  Word(label='bp', operation='-', hash=18, focal_length=None),
#  Word(label='nv', operation='-', hash=4, focal_length=None),
#  Word(label='dhpbb', operation='-', hash=160, focal_length=None),
#  Word(label='zv', operation='=', hash=144, focal_length=2),
#  Word(label='msv', operation='-', hash=134, focal_length=None),
#  Word(label='dj', operation='=', hash=238, focal_length=4),
#  Word(label='qv', operation='-', hash=103, focal_length=None),
#  Word(label='cr', operation='=', hash=85, focal_length=9),
#  Word(label='pcd', operation='=', hash=215, focal_length=8),
#  Word(label='nzv', operation='-', hash=158, focal_length=None),
#  Word(label='dgdtp', operation='-', hash=83, focal_length=None),
#  Word(label='dm', operation='=', hash=33, focal_length=1),
#  Word(label='chf', operation='=', hash=33, focal_length=8),
#  Word(label='hv', operation='=', hash=62, focal_length=9),
#  Word(label='trn', operation='=', hash=52, focal_length=1),
#  Word(label='bblqrt', operation='-', hash=151, focal_length=None),
#  Word(label='ggz', operation='-', hash=24, focal_length=None),
#  Word(label='jmq', operation='=', hash=216, focal_length=1),
#  Word(label='kmpq', operation='-', hash=249, focal_length=None),
#  Word(label='gg', operation='=', hash=30, focal_length=3),
#  Word(label='ptl', operation='-', hash=144, focal_length=None),
#  Word(label='tsbk', operation='=', hash=52, focal_length=7),
#  Word(label='nrv', operation='=', hash=150, focal_length=3),
#  Word(label='lt', operation='=', hash=160, focal_length=9),
#  Word(label='hdt', operation='=', hash=128, focal_length=4),
#  Word(label='dhbn', operation='=', hash=60, focal_length=4),
#  Word(label='ptl', operation='=', hash=144, focal_length=9),
#  Word(label='tzf', operation='-', hash=180, focal_length=None),
#  Word(label='xrn', operation='-', hash=248, focal_length=None),
#  Word(label='ppnc', operation='=', hash=161, focal_length=8),
#  Word(label='tcc', operation='=', hash=138, focal_length=5),
#  Word(label='tcjb', operation='=', hash=147, focal_length=4),
#  Word(label='hck', operation='-', hash=198, focal_length=None),
#  Word(label='vpgfjs', operation='-', hash=32, focal_length=None),
#  Word(label='dm', operation='=', hash=33, focal_length=1),
#  Word(label='gg', operation='=', hash=30, focal_length=9),
#  Word(label='dl', operation='=', hash=16, focal_length=5),
#  Word(label='bpq', operation='-', hash=179, focal_length=None),
#  Word(label='bc', operation='-', hash=53, focal_length=None),
#  Word(label='dfm', operation='=', hash=135, focal_length=2),
#  Word(label='ljq', operation='-', hash=215, focal_length=None),
#  Word(label='zfxr', operation='-', hash=138, focal_length=None),
#  Word(label='kgn', operation='=', hash=16, focal_length=7),
#  Word(label='tcjb', operation='-', hash=147, focal_length=None),
#  Word(label='kqd', operation='-', hash=176, focal_length=None),
#  Word(label='jgmh', operation='=', hash=150, focal_length=2),
#  Word(label='rm', operation='-', hash=239, focal_length=None),
#  Word(label='lntx', operation='=', hash=102, focal_length=6),
#  Word(label='fzm', operation='=', hash=125, focal_length=9),
#  Word(label='bkx', operation='-', hash=133, focal_length=None),
#  Word(label='sxfqnm', operation='=', hash=125, focal_length=8),
#  Word(label='nprdk', operation='=', hash=15, focal_length=4),
#  Word(label='zbm', operation='-', hash=57, focal_length=None),
#  Word(label='vft', operation='=', hash=112, focal_length=9),
#  Word(label='jp', operation='-', hash=26, focal_length=None),
#  Word(label='cdf', operation='=', hash=157, focal_length=4),
#  Word(label='dz', operation='-', hash=254, focal_length=None),
#  Word(label='cqp', operation='-', hash=244, focal_length=None),
#  Word(label='cnn', operation='-', hash=111, focal_length=None),
#  Word(label='nxgxx', operation='-', hash=109, focal_length=None),
#  Word(label='ljq', operation='=', hash=215, focal_length=3),
#  Word(label='pm', operation='=', hash=173, focal_length=7),
#  Word(label='mhxd', operation='-', hash=177, focal_length=None),
#  Word(label='gshf', operation='-', hash=88, focal_length=None),
#  Word(label='fx', operation='=', hash=30, focal_length=1),
#  Word(label='qfj', operation='=', hash=209, focal_length=4),
#  Word(label='qnm', operation='-', hash=12, focal_length=None),
#  Word(label='xzt', operation='-', hash=102, focal_length=None),
#  Word(label='gx', operation='-', hash=63, focal_length=None),
#  Word(label='lntx', operation='-', hash=102, focal_length=None),
#  Word(label='fkgtl', operation='-', hash=72, focal_length=None),
#  Word(label='nbh', operation='=', hash=152, focal_length=1),
#  Word(label='qttxq', operation='=', hash=98, focal_length=5),
#  Word(label='fjdjn', operation='-', hash=76, focal_length=None),
#  Word(label='hzr', operation='=', hash=52, focal_length=4),
#  Word(label='kph', operation='-', hash=211, focal_length=None),
#  Word(label='nsmvkh', operation='=', hash=7, focal_length=9),
#  Word(label='qfp', operation='-', hash=55, focal_length=None),
#  Word(label='dr', operation='=', hash=118, focal_length=2),
#  Word(label='xkl', operation='=', hash=239, focal_length=4),
#  Word(label='hmm', operation='-', hash=50, focal_length=None),
#  Word(label='nzv', operation='-', hash=158, focal_length=None),
#  Word(label='njnn', operation='=', hash=180, focal_length=2),
#  Word(label='rzd', operation='-', hash=48, focal_length=None),
#  Word(label='sdjrvt', operation='=', hash=221, focal_length=5),
#  Word(label='qz', operation='=', hash=171, focal_length=2),
#  Word(label='zlbv', operation='=', hash=30, focal_length=5),
#  Word(label='tc', operation='=', hash=135, focal_length=3),
#  Word(label='dztd', operation='=', hash=86, focal_length=3),
#  Word(label='bh', operation='-', hash=138, focal_length=None),
#  Word(label='btfm', operation='=', hash=121, focal_length=5),
#  Word(label='chk', operation='=', hash=118, focal_length=1),
#  Word(label='gnf', operation='-', hash=171, focal_length=None),
#  Word(label='gds', operation='-', hash=62, focal_length=None),
#  Word(label='qnm', operation='-', hash=12, focal_length=None),
#  Word(label='dp', operation='-', hash=84, focal_length=None),
#  Word(label='hdt', operation='-', hash=128, focal_length=None),
#  Word(label='gdf', operation='=', hash=97, focal_length=9),
#  Word(label='jxlg', operation='=', hash=165, focal_length=6),
#  Word(label='hcld', operation='=', hash=235, focal_length=8),
#  Word(label='qqlx', operation='=', hash=54, focal_length=3),
#  Word(label='mmmznv', operation='=', hash=213, focal_length=5),
#  Word(label='cpc', operation='-', hash=246, focal_length=None),
#  Word(label='zt', operation='-', hash=110, focal_length=None),
#  Word(label='tsnv', operation='=', hash=123, focal_length=2),
#  Word(label='hb', operation='-', hash=234, focal_length=None),
#  Word(label='nh', operation='-', hash=22, focal_length=None),
#  Word(label='rnx', operation='-', hash=248, focal_length=None),
#  Word(label='np', operation='-', hash=158, focal_length=None),
#  Word(label='fq', operation='-', hash=167, focal_length=None),
#  Word(label='zbs', operation='-', hash=159, focal_length=None),
#  Word(label='pkx', operation='=', hash=51, focal_length=2),
#  Word(label='nkg', operation='-', hash=176, focal_length=None),
#  Word(label='dhpbb', operation='-', hash=160, focal_length=None),
#  Word(label='nzv', operation='=', hash=158, focal_length=8),
#  Word(label='dr', operation='=', hash=118, focal_length=9),
#  Word(label='rm', operation='-', hash=239, focal_length=None),
#  Word(label='cgjdd', operation='-', hash=76, focal_length=None),
#  Word(label='nxgxx', operation='=', hash=109, focal_length=4),
#  Word(label='jjr', operation='=', hash=134, focal_length=5),
#  Word(label='rmfb', operation='-', hash=119, focal_length=None),
#  Word(label='vlftj', operation='-', hash=70, focal_length=None),
#  Word(label='kqd', operation='-', hash=176, focal_length=None),
#  Word(label='hb', operation='=', hash=234, focal_length=7),
#  Word(label='rn', operation='=', hash=0, focal_length=3),
#  Word(label='pf', operation='-', hash=54, focal_length=None),
#  Word(label='lzb', operation='-', hash=232, focal_length=None),
#  Word(label='qpp', operation='=', hash=129, focal_length=6),
#  Word(label='pm', operation='=', hash=173, focal_length=2),
#  Word(label='zjlc', operation='=', hash=195, focal_length=5),
#  Word(label='kjzp', operation='-', hash=159, focal_length=None),
#  Word(label='nbh', operation='-', hash=152, focal_length=None),
#  Word(label='lrspkv', operation='=', hash=66, focal_length=6),
#  Word(label='ls', operation='=', hash=143, focal_length=5),
#  Word(label='pkx', operation='-', hash=51, focal_length=None),
#  Word(label='vlftj', operation='-', hash=70, focal_length=None),
#  Word(label='tcm', operation='-', hash=52, focal_length=None),
#  Word(label='drbrb', operation='=', hash=140, focal_length=1),
#  Word(label='qnm', operation='-', hash=12, focal_length=None),
#  Word(label='bdt', operation='=', hash=90, focal_length=8),
#  Word(label='chf', operation='=', hash=33, focal_length=9),
#  Word(label='dpcsth', operation='=', hash=86, focal_length=5),
#  Word(label='nc', operation='=', hash=193, focal_length=2),
#  Word(label='jbsv', operation='-', hash=85, focal_length=None),
#  Word(label='kms', operation='=', hash=43, focal_length=4),
#  Word(label='qtn', operation='=', hash=227, focal_length=3),
#  Word(label='tzx', operation='-', hash=230, focal_length=None),
#  Word(label='cz', operation='-', hash=221, focal_length=None),
#  Word(label='cbkm', operation='-', hash=237, focal_length=None),
#  Word(label='ddf', operation='-', hash=206, focal_length=None),
#  Word(label='kxn', operation='-', hash=65, focal_length=None),
#  Word(label='pcm', operation='-', hash=112, focal_length=None),
#  Word(label='jx', operation='=', hash=162, focal_length=1),
#  Word(label='gpv', operation='-', hash=253, focal_length=None),
#  Word(label='mmrbd', operation='-', hash=66, focal_length=None),
#  Word(label='rtpfj', operation='-', hash=38, focal_length=None),
#  Word(label='gnm', operation='-', hash=34, focal_length=None),
#  Word(label='km', operation='-', hash=8, focal_length=None),
#  Word(label='cf', operation='-', hash=137, focal_length=None),
#  Word(label='zlv', operation='=', hash=28, focal_length=9),
#  Word(label='zljm', operation='=', hash=141, focal_length=5),
#  Word(label='sdjrvt', operation='-', hash=221, focal_length=None),
#  Word(label='lszh', operation='=', hash=17, focal_length=7),
#  Word(label='dztd', operation='-', hash=86, focal_length=None),
#  Word(label='lcv', operation='=', hash=69, focal_length=4),
#  Word(label='zpjcm', operation='-', hash=84, focal_length=None),
#  Word(label='gx', operation='=', hash=63, focal_length=2),
#  Word(label='kqb', operation='=', hash=142, focal_length=3),
#  Word(label='smc', operation='=', hash=163, focal_length=4),
#  Word(label='jcb', operation='=', hash=143, focal_length=5),
#  Word(label='pc', operation='-', hash=3, focal_length=None),
#  Word(label='sbk', operation='-', hash=192, focal_length=None),
#  Word(label='rz', operation='=', hash=204, focal_length=4),
#  Word(label='qpv', operation='=', hash=231, focal_length=3),
#  Word(label='zf', operation='=', hash=128, focal_length=8),
#  Word(label='lcv', operation='=', hash=69, focal_length=7),
#  Word(label='xnj', operation='=', hash=48, focal_length=7),
#  Word(label='xkl', operation='=', hash=239, focal_length=2),
#  Word(label='nrnv', operation='=', hash=196, focal_length=4),
#  Word(label='fzb', operation='=', hash=194, focal_length=7),
#  Word(label='gxp', operation='-', hash=159, focal_length=None),
#  Word(label='gvh', operation='=', hash=213, focal_length=6),
#  Word(label='tt', operation='=', hash=168, focal_length=8),
#  Word(label='kqd', operation='=', hash=176, focal_length=4),
#  Word(label='xmp', operation='-', hash=117, focal_length=None),
#  Word(label='cthz', operation='-', hash=217, focal_length=None),
#  Word(label='fsqtxt', operation='-', hash=26, focal_length=None),
#  Word(label='drbrb', operation='=', hash=140, focal_length=3),
#  Word(label='zrqm', operation='-', hash=154, focal_length=None),
#  Word(label='qrz', operation='-', hash=109, focal_length=None),
#  Word(label='zfjdds', operation='-', hash=21, focal_length=None),
#  Word(label='hvh', operation='-', hash=6, focal_length=None),
#  Word(label='nzq', operation='=', hash=73, focal_length=8),
#  Word(label='gld', operation='=', hash=71, focal_length=8),
#  Word(label='lhd', operation='-', hash=184, focal_length=None),
#  Word(label='mcl', operation='-', hash=204, focal_length=None),
#  Word(label='vglgq', operation='=', hash=241, focal_length=6),
#  Word(label='ptq', operation='-', hash=229, focal_length=None),
#  Word(label='mnn', operation='=', hash=89, focal_length=9),
#  Word(label='hk', operation='=', hash=131, focal_length=7),
#  Word(label='nrnv', operation='=', hash=196, focal_length=8),
#  Word(label='hk', operation='=', hash=131, focal_length=8),
#  Word(label='dz', operation='=', hash=254, focal_length=2),
#  Word(label='vjqsfl', operation='-', hash=70, focal_length=None),
#  Word(label='ksns', operation='=', hash=255, focal_length=2),
#  Word(label='dj', operation='=', hash=238, focal_length=6),
#  Word(label='kqb', operation='-', hash=142, focal_length=None),
#  Word(label='np', operation='=', hash=158, focal_length=1),
#  Word(label='fsqtxt', operation='=', hash=26, focal_length=8),
#  Word(label='gg', operation='=', hash=30, focal_length=2),
#  Word(label='kxn', operation='-', hash=65, focal_length=None),
#  Word(label='slsz', operation='=', hash=204, focal_length=9),
#  Word(label='hxl', operation='-', hash=140, focal_length=None),
#  Word(label='tt', operation='=', hash=168, focal_length=1),
#  Word(label='zbs', operation='=', hash=159, focal_length=8),
#  Word(label='zv', operation='=', hash=144, focal_length=6),
#  Word(label='ljr', operation='=', hash=232, focal_length=6),
#  Word(label='cdf', operation='=', hash=157, focal_length=1),
#  Word(label='vpgfjs', operation='=', hash=32, focal_length=1),
#  Word(label='fxkm', operation='-', hash=230, focal_length=None),
#  Word(label='dmzntl', operation='-', hash=137, focal_length=None),
#  Word(label='stv', operation='=', hash=205, focal_length=9),
#  Word(label='chf', operation='-', hash=33, focal_length=None),
#  Word(label='clf', operation='=', hash=165, focal_length=7),
#  Word(label='qzcb', operation='-', hash=80, focal_length=None),
#  Word(label='mmrbd', operation='=', hash=66, focal_length=1),
#  Word(label='ff', operation='=', hash=236, focal_length=2),
#  Word(label='gnzd', operation='-', hash=147, focal_length=None),
#  Word(label='szs', operation='-', hash=96, focal_length=None),
#  Word(label='smc', operation='=', hash=163, focal_length=8),
#  Word(label='qzcb', operation='-', hash=80, focal_length=None),
#  Word(label='jmq', operation='=', hash=216, focal_length=5),
#  Word(label='zfjdds', operation='=', hash=21, focal_length=9),
#  Word(label='gqgd', operation='=', hash=179, focal_length=6),
#  Word(label='nrf', operation='=', hash=134, focal_length=7),
#  Word(label='gnm', operation='=', hash=34, focal_length=5),
#  Word(label='kp', operation='-', hash=59, focal_length=None),
#  Word(label='kbp', operation='-', hash=141, focal_length=None),
#  Word(label='npkcv', operation='=', hash=82, focal_length=7),
#  Word(label='csv', operation='-', hash=156, focal_length=None),
#  Word(label='bscdp', operation='-', hash=124, focal_length=None),
#  Word(label='xh', operation='=', hash=96, focal_length=8),
#  Word(label='scjz', operation='-', hash=234, focal_length=None),
#  Word(label='fhd', operation='-', hash=146, focal_length=None),
#  Word(label='mhxd', operation='=', hash=177, focal_length=4),
#  Word(label='dfm', operation='=', hash=135, focal_length=1),
#  Word(label='qnm', operation='-', hash=12, focal_length=None),
#  Word(label='grs', operation='=', hash=12, focal_length=1),
#  Word(label='tzx', operation='=', hash=230, focal_length=9),
#  Word(label='nkg', operation='-', hash=176, focal_length=None),
#  Word(label='ccj', operation='=', hash=192, focal_length=2),
#  Word(label='kv', operation='-', hash=161, focal_length=None),
#  Word(label='xkl', operation='-', hash=239, focal_length=None),
#  Word(label='zpjcm', operation='=', hash=84, focal_length=8),
#  Word(label='mx', operation='=', hash=5, focal_length=8),
#  Word(label='qqvn', operation='-', hash=214, focal_length=None),
#  Word(label='kch', operation='-', hash=38, focal_length=None),
#  Word(label='hq', operation='-', hash=233, focal_length=None),
#  Word(label='fxvvt', operation='-', hash=62, focal_length=None),
#  Word(label='ql', operation='=', hash=189, focal_length=6),
#  Word(label='dj', operation='-', hash=238, focal_length=None),
#  Word(label='lcc', operation='-', hash=2, focal_length=None),
#  Word(label='jgmh', operation='=', hash=150, focal_length=9),
#  Word(label='tzx', operation='=', hash=230, focal_length=3),
#  Word(label='lntx', operation='-', hash=102, focal_length=None),
#  Word(label='gvh', operation='-', hash=213, focal_length=None),
#  Word(label='nbd', operation='-', hash=84, focal_length=None),
#  Word(label='xrn', operation='-', hash=248, focal_length=None),
#  Word(label='qrz', operation='=', hash=109, focal_length=6),
#  Word(label='kv', operation='=', hash=161, focal_length=9),
#  Word(label='qpv', operation='-', hash=231, focal_length=None),
#  ...]

# %%
from typing import Dict, Tuple

boxes: Dict[int, Dict[str, int]] = {}

for word in words:
    if word.hash not in boxes:
        boxes[word.hash] = {}
    if word.operation == '-':
        boxes[word.hash].pop(word.label, None)
    else:
        boxes[word.hash][word.label] = word.focal_length

boxes
# Out:
# {53: {'bvm': 9, 'tcllf': 2},
#  91: {},
#  251: {'hc': 1, 'gt': 7},
#  130: {},
#  221: {},
#  229: {'ptq': 8, 'kz': 4},
#  193: {'scqj': 1},
#  124: {'flj': 6},
#  121: {'tbs': 8, 'btfm': 5},
#  76: {'cgjdd': 1, 'zr': 5},
#  192: {'sbk': 4},
#  139: {'jbkdsm': 2},
#  202: {'jfzcm': 2, 'pkbm': 2},
#  152: {'nbh': 2},
#  234: {'scjz': 6},
#  98: {'qttxq': 5},
#  80: {},
#  129: {'xpsf': 8, 'jg': 2},
#  94: {'kc': 4, 'nvz': 9, 'zd': 5},
#  128: {'fsqsc': 3},
#  178: {'mkj': 9, 'fxt': 1},
#  132: {'gsnbj': 9},
#  40: {},
#  188: {'rj': 6},
#  141: {'kbp': 2},
#  26: {},
#  57: {},
#  126: {},
#  206: {'ddf': 5},
#  137: {'dmzntl': 1, 'cf': 4, 'qx': 5},
#  61: {'jc': 1},
#  96: {'szs': 1},
#  236: {'ff': 8},
#  125: {'fzm': 2, 'sxfqnm': 7},
#  84: {'dp': 8},
#  246: {'lj': 6},
#  244: {'cqp': 8, 'nf': 3},
#  36: {'bb': 8},
#  165: {'clf': 8},
#  226: {'msbxx': 3},
#  112: {},
#  18: {'trl': 2},
#  209: {'ns': 7, 'ksxkbn': 3, 'zsd': 5},
#  134: {'msv': 5, 'nrf': 3},
#  58: {'tbdbvh': 8, 'zdxd': 8},
#  184: {'lhd': 6, 'vb': 3},
#  203: {'sx': 2, 'nbk': 5},
#  90: {},
#  245: {},
#  213: {'mmmznv': 1, 'gvh': 7, 'zk': 1},
#  248: {'jn': 2, 'xrn': 8},
#  56: {},
#  46: {'vdt': 5},
#  158: {'jqrkf': 1, 'nzv': 8},
#  159: {'qtj': 1, 'gxp': 6, 'zbs': 1},
#  235: {'gd': 4},
#  241: {'pq': 7, 'rhltg': 5},
#  146: {'smb': 2, 'fvv': 1},
#  50: {'vpl': 8, 'dn': 6, 'hmm': 6},
#  160: {'mc': 5, 'dhpbb': 1},
#  131: {'hk': 5, 'vnlc': 8, 'rpdm': 9},
#  172: {},
#  123: {},
#  86: {'dztd': 2, 'cc': 4},
#  223: {'bgv': 4, 'rtfc': 6},
#  168: {},
#  97: {},
#  232: {'ljr': 6, 'lzb': 1, 'prf': 5, 'cslv': 8},
#  10: {'xr': 7},
#  51: {'pkx': 2},
#  110: {'zt': 3, 'ks': 6},
#  136: {},
#  133: {'bkx': 3},
#  65: {},
#  135: {'dfm': 7, 'mrx': 5},
#  109: {'nxgxx': 9, 'jqr': 8},
#  55: {'ljjg': 1, 'qfp': 6},
#  103: {'qv': 8, 'kvvp': 6, 'cd': 6, 'zgf': 2, 'qhbl': 1},
#  154: {'zrqm': 5, 'rh': 1, 'cg': 2},
#  30: {'fx': 1, 'kncgk': 3, 'zlbv': 9},
#  140: {'ltff': 8, 'hxl': 5},
#  73: {'nzq': 1},
#  199: {'kzr': 4, 'dsxh': 8},
#  150: {'jgmh': 6, 'pmnk': 5, 'fp': 9},
#  44: {'xt': 8},
#  11: {},
#  217: {'cthz': 5, 'vs': 1},
#  85: {'cr': 5},
#  0: {},
#  163: {'kmk': 4},
#  4: {'fxnx': 9},
#  117: {},
#  38: {'kch': 3, 'rtpfj': 8},
#  48: {'rzd': 5, 'nrp': 8, 'pjdr': 9},
#  33: {'rzkj': 6},
#  225: {},
#  31: {'pnq': 6},
#  237: {'cbkm': 3, 'sz': 7},
#  69: {'rc': 4, 'lcv': 8, 'qt': 3},
#  179: {'bpq': 7, 'kh': 3},
#  43: {'qvmctp': 2, 'kms': 9},
#  233: {'hq': 1},
#  211: {'kph': 5},
#  119: {'dc': 3, 'zgxn': 2},
#  138: {},
#  7: {'vlsr': 7, 'lk': 3, 'nsmvkh': 8},
#  82: {'frz': 2},
#  127: {'gscr': 7},
#  231: {'qpv': 1},
#  186: {'dv': 6, 'dfp': 5},
#  153: {'gthv': 6},
#  6: {'lz': 4},
#  216: {'jmq': 1},
#  20: {'qvm': 3},
#  252: {'sxq': 6},
#  52: {'hzr': 3, 'tcm': 5},
#  29: {'fsqs': 6},
#  3: {'pc': 2},
#  190: {'dbx': 2},
#  162: {},
#  62: {'hv': 2, 'fxvvt': 4, 'gds': 5, 'xf': 6},
#  166: {},
#  75: {'fxlq': 4},
#  12: {'vv': 2, 'vss': 6, 'grs': 6},
#  210: {'xft': 2, 'mmh': 4},
#  42: {},
#  66: {'rxx': 1, 'mmrbd': 6},
#  157: {'cdf': 2},
#  147: {'gnzd': 3, 'tcjb': 2, 'xk': 8},
#  144: {'zpf': 2},
#  28: {'qmdpz': 1, 'zlv': 5},
#  149: {'gn': 9, 'vdk': 2},
#  197: {'qczst': 3},
#  21: {'zfjdds': 5, 'jtg': 3, 'vdhc': 5},
#  194: {},
#  176: {'nkg': 9, 'kqd': 8},
#  205: {'stv': 3},
#  142: {},
#  214: {'qqvn': 1},
#  254: {'dz': 7, 'dgc': 9},
#  249: {'kmpq': 7},
#  215: {'ljq': 5},
#  177: {'mhxd': 8},
#  230: {'sgfv': 2, 'vhbdb': 6},
#  5: {'mx': 9},
#  70: {'vjqsfl': 4},
#  189: {},
#  59: {},
#  72: {'nz': 1},
#  67: {'qkg': 2},
#  118: {'chk': 5, 'gxjgv': 9},
#  17: {},
#  204: {'slsz': 7, 'mcl': 3, 'rz': 2},
#  104: {'lgzsh': 7},
#  8: {'zn': 7},
#  93: {'zs': 6},
#  173: {'pm': 4},
#  161: {'kv': 9},
#  174: {},
#  239: {'rm': 9, 'xkl': 9},
#  218: {'vd': 4, 'gc': 2},
#  15: {'tk': 9, 'nprdk': 4},
#  111: {'cnn': 4, 'jfdk': 9},
#  13: {'gf': 3},
#  175: {},
#  71: {},
#  37: {},
#  102: {'xzt': 8, 'lntx': 1, 'sc': 9},
#  116: {'fn': 4},
#  106: {'vkxq': 8},
#  77: {'kb': 2, 'fglrb': 4},
#  167: {'fq': 3},
#  99: {'fm': 6},
#  87: {},
#  195: {'zjlc': 7},
#  24: {'ggz': 2},
#  39: {'mz': 9},
#  101: {},
#  220: {},
#  208: {'rdz': 9},
#  32: {'vpgfjs': 9},
#  238: {'qxrc': 1},
#  240: {},
#  155: {'qj': 8},
#  63: {},
#  151: {'bblqrt': 8},
#  107: {},
#  183: {'zktn': 1},
#  224: {},
#  196: {'nrnv': 3},
#  115: {'vm': 3},
#  108: {'fkk': 8},
#  227: {'qtn': 4},
#  41: {},
#  143: {'jcb': 5, 'xts': 4, 'ls': 2},
#  2: {},
#  22: {},
#  171: {'qz': 1, 'gnf': 4},
#  212: {},
#  54: {'fnb': 9, 'pf': 5, 'qqlx': 3},
#  169: {'qrnx': 3},
#  222: {},
#  180: {'njnn': 7},
#  120: {'rf': 5},
#  19: {'lcd': 2},
#  156: {'csv': 5},
#  228: {},
#  170: {},
#  83: {},
#  16: {'kgn': 5},
#  74: {'mm': 4},
#  60: {'dhbn': 8, 'zb': 2},
#  198: {'hck': 4},
#  88: {},
#  253: {},
#  34: {'gnm': 8},
#  89: {},
#  255: {},
#  25: {'gvzvxt': 9},
#  145: {'zg': 8},
#  68: {'rr': 4},
#  181: {},
#  79: {}}

# %%
answer = 0
for box_num, lenses in boxes.items():
    for idx, (label, focal_length) in enumerate(lenses.items()):
        answer += (box_num + 1) * (idx + 1) * focal_length
answer
# Out:
# 244403
